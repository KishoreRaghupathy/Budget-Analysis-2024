# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("union_list_2024.csv")
data.head()
# Out:
#                    Department /Ministry  Fund allotted(in ₹crores)
# 0               MINISTRY OF AGRICULTURE                  125035.79
# 1           DEPARTMENT OF ATOMIC ENERGY                   25078.49
# 2            MINISTRY OF AYURVEDA, YOGA                    3647.50
# 3  MINISTRY OF CHEMICALS AND FERTILISER                  178481.99
# 4            MINISTRY OF CIVIL AVIATION                    3113.36

# %%
print(data)
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data.isnull()
# Out:
#     Department /Ministry  Fund allotted(in ₹crores)
# 0                  False                      False
# 1                  False                      False
# 2                  False                      False
# 3                  False                      False
# 4                  False                      False
# 5                  False                      False
# 6                  False                      False
# 7                  False                      False
# 8                  False                      False
# 9                  False                      False
# 10                 False                      False
# 11                 False                      False
# 12                 False                      False
# 13                 False                      False
# 14                 False                      False
# 15                 False                      False
# 16                 False                      False
# ...

# %%
data.dropna()
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
#for selective ministry details
data=pd.read_csv("union_list_2024.csv")
data= data.iloc[[0,8,11,14,18,23,41,42,43],:]
print(data)
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 0                  MINISTRY OF AGRICULTURE                  125035.79
# 8             MINISTRY OF CONSUMER AFFAIRS                   97579.05
# 11                     MINISTRY OF DEFENCE                  593537.64
# 14                   MINISTRY OF EDUCATION                  112899.47
# 18                     MINISTRY OF FINANCE                 1689719.17
# 23                MINISTRY OF HOME AFFAIRS                  196034.94
# 41                    MINISTRY OF RAILWAYS                  241267.51
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                  270434.71
# 43           MINISTRY OF RURAL DEVELOPMENT                  159964.23

# %%
#For searching ministry's index
search_term ="MINISTRY OF RAILWAYS"
matches =data[data['Department /Ministry'].str.contains(search_term, case=False, na=False)]

if not matches.empty:
    print(f"The term '{search_term}' is found in the following rows (based on the 'ministry' column):")
    print(matches)
else:
    print(f"No matches found for '{search_term}' in the 'ministry' column.")
# Out:
# The term 'MINISTRY OF RAILWAYS' is found in the following rows (based on the 'ministry' column):
#     Department /Ministry  Fund allotted(in ₹crores)
# 41  MINISTRY OF RAILWAYS                  241267.51

# %%
selective_ministry=data
print(data)
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 0                  MINISTRY OF AGRICULTURE                  125035.79
# 8             MINISTRY OF CONSUMER AFFAIRS                   97579.05
# 11                     MINISTRY OF DEFENCE                  593537.64
# 14                   MINISTRY OF EDUCATION                  112899.47
# 18                     MINISTRY OF FINANCE                 1689719.17
# 23                MINISTRY OF HOME AFFAIRS                  196034.94
# 41                    MINISTRY OF RAILWAYS                  241267.51
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                  270434.71
# 43           MINISTRY OF RURAL DEVELOPMENT                  159964.23

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)')
# Out:
# <Axes: xlabel='Department /Ministry'>

# %%
df = data["Fund allotted(in ₹crores)"]
labels = data["Department /Ministry"]
plt.figure(figsize=(7,7))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget", fontsize=20)
plt.show()
